# %%
import pandas as pd
import numpy as np
import os
from importlib import reload

# local code
import sys
sys.path.append("../source/")

# %%
# DATA PATHS
czi_path = "/nfs/turbo/umms-indikar/shared/projects/live_cell_imaging/PIP_FUCCI_ANALYSIS/wh17/WH-17-10-13-21-01(3).czi"
trackmate_path = "/nfs/turbo/umms-indikar/shared/projects/live_cell_imaging/PIP_FUCCI_ANALYSIS/wh17/spots.csv"

# global vars
DATA_NAME = "wh17" # for figure/artifact naming

# %%
df = pd.read_csv(trackmate_path, skiprows=[1, 2, 3])

print(df.shape)
df.head()
# Out:
# (214898, 46)
#     LABEL    ID  TRACK_ID   QUALITY   POSITION_X   POSITION_Y  POSITION_Z  \
# 0  ID2048  2048       0.0  0.881755   378.892277  1275.882220         0.0
# 1  ID2049  2049       1.0  0.881288  2546.617345   595.827218         0.0
# 2  ID2050  2050       2.0  0.880880  1413.473149  2276.756729         0.0
# 3  ID2051  2051       3.0  0.880714  2840.339787   350.596714         0.0
# 4  ID2052  2052       4.0  0.880067  2321.230790  1677.189471         0.0
#
#    POSITION_T  FRAME     RADIUS  ...  ELLIPSE_X0  ELLIPSE_Y0  ELLIPSE_MAJOR  \
# 0         0.0      0   9.373108  ...   -0.025051    0.004838      12.159079
# 1         0.0      0   9.388981  ...    0.010721   -0.032076      10.979096
# 2         0.0      0  10.267726  ...   -0.034062    0.011548      12.985505
# 3         0.0      0   8.714505  ...   -0.000233   -0.016225      10.847612
# 4         0.0      0  11.210600  ...   -0.027172   -0.016732      13.826768
#
# ...
